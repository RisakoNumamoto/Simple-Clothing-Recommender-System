# %%
import json
rent_list = list()
category_set=set()
body_type_set=set()
rent_for_set=set()
with open('renttherunway_final_data.json') as json_data:
    # read all data in
    for line in json_data:
        rent_entry = json.loads(line.strip())
        # some lines don't have ratings. raing values: 2, 4, 6, 8, 10, null.
        # need to replace 0 for a user's mean ratings later
        # ? uid, iid, rating: we only keep those lines that have ratings. 
        # This is called sparse-matrix form
        rent_extracted_entry = dict()
        if rent_entry['rating']:
            rent_extracted_entry['rating'] = float(rent_entry['rating'])
            
            
            rent_extracted_entry['user_id'] = rent_entry['user_id']
            rent_extracted_entry['item_id'] = rent_entry['item_id']
        
            # first filter data according to users' choice: category, body type, rented for
            # body type and rented for can be empty
            rent_extracted_entry['category'] = rent_entry['category']
            # some users didn't provide information of rented for or body type
            rent_extracted_entry['body type'] = rent_entry.get('body type', '')
            rent_extracted_entry['rented for'] = rent_entry.get('rented for', '')
            # To get category set, rented for set, body type set
            category_set.add(rent_entry['category'])
            rent_for_set.add(rent_extracted_entry['rented for'])
            body_type_set.add(rent_extracted_entry['body type'])
            rent_list.append(rent_extracted_entry)


print("Category:")            
print(category_set)
"""
print()
print("Body Type:")
print(body_type_set)
print()
print("Ocasion")
print(rent_for_set)
"""
# rent_list is a list of dictionaries, each dictionary contains fields: <uid, iid, rating, 
# category, body type, rented for>.
# Out:
# Category:
# set([u'mini', u'vest', u'buttondown', u'gown', u'tunic', u'overcoat', u'jeans', u'tee', u'down', u'kaftan', u'peacoat', u'sheath', u'sweatshirt', u'bomber', u'skirt', u'jumpsuit', u'blouse', u'jacket', u'frock', u'tank', u'shirt', u'for', u'jogger', u'dress', u'top', u'pant', u'kimono', u'pullover', u'tight', u'ballgown', u'maxi', u'suit', u'print', u'parka', u'pants', u'sweatpants', u'trouser', u'poncho', u'culotte', u'caftan', u'combo', u'legging', u't-shirt', u'turtleneck', u'crewneck', u'cardigan', u'leggings', u'hoodie', u'cape', u'overalls', u'culottes', u'knit', u'blazer', u'duster', u'coat', u'midi', u'blouson', u'romper', u'trench', u'henley', u'cami', u'shirtdress', u'shift', u'trousers', u'skort', u'sweatershirt', u'sweater', u'skirts'])
# '\nprint()\nprint("Body Type:")\nprint(body_type_set)\nprint()\nprint("Ocasion")\nprint(rent_for_set)\n'

# %%
from tkinter import *

def sel():
    #selection = "You selected " + str(v.get())
    selection = v.get()
    if selection == 1:
        selection = 'jacket'
    elif selection == 2:
        selection = "down"
    elif selection == 3:
        selection = "buttondown"
    elif selection == 4:
        selection = "crewneck"
    elif selection == 5:
        selection = "gown"
    elif selection == 6:
        selection = "hoodie"
    elif selection == 7:
        selection = "caftan"
    elif selection == 8:
        selection = "sheath"
    elif selection == 9:
        selection = "leggings"
    elif selection == 10:
        selection = "tank"
    elif selection == 11:
        selection = "tunic"
    elif selection == 12:
        selection = "turtleneck"
    elif selection == 13:
        selection = "skirts"
    elif selection == 14:
        selection = "parka"
    elif selection == 15:
        selection = "sweatershirt"
    elif selection == 16:
        selection = "jeans"
    elif selection == 17:
        selection = "romper"
    elif selection == 18:
        selection = "sweater"
    elif selection == 19:
        selection = "pullover"
    elif selection == 20:
        selection = "jogger"
    elif selection == 21:
        selection = "tee"

    elif selection == 22:
        selection = "trench"
    elif selection == 23:
        selection = "trousers"
    elif selection == 24:
        selection = "jacket"
    elif selection == 25:
        selection = "sweatshirt"
    elif selection == 26:
        selection = "kaftan"
    elif selection == 27:
        selection = "suit"
    elif selection == 28:
        selection = "shift"
    elif selection == 29:
        selection = "mini"
    elif selection == 30:
        selection = "coat"
    elif selection == 31:
        selection = "trouser"
    elif selection == 32:
        selection = "cape"
    elif selection == 33:
        selection = "top"
    
    #print(selection)
    return selection

"""
'overalls', 'blouson', 't-shirt', 'culotte', 'jumpsuit', 'shirtdress', 'duster', 'kimono', 'combo', 'pant', 'culottes', 
'shirt', 'blazer', 'frock', 'pants', 'midi', 'skirt', 'print', 'overcoat', 'for', 'dress', 'cardigan', 'sweatpants', 
'cami', 'skort', 'peacoat', 'knit', 'maxi', 'tight', 'blouse', 'vest', 'bomber', 'poncho', 'henley'
"""
    
root = Tk() 
v = IntVar() 
Radiobutton(root, text='Legging', variable=v, value=1, command=sel).pack(anchor=W) 
Radiobutton(root, text='Down', variable=v, value=2, command=sel).pack(anchor=W) 
Radiobutton(root, text='Buttondown', variable=v, value=3, command=sel).pack(anchor=W)
Radiobutton(root, text='Crewneck', variable=v, value=4, command=sel).pack(anchor=W) 
Radiobutton(root, text='Gown', variable=v, value=5, command=sel).pack(anchor=W) 
Radiobutton(root, text='Hoodie', variable=v, value=6, command=sel).pack(anchor=W)
Radiobutton(root, text='Caftan', variable=v, value=7, command=sel).pack(anchor=W) 
Radiobutton(root, text='Sheath', variable=v, value=8, command=sel).pack(anchor=W) 
Radiobutton(root, text='Leggings', variable=v, value=9, command=sel).pack(anchor=W)
Radiobutton(root, text='Tank', variable=v, value=10, command=sel).pack(anchor=W) 

Radiobutton(root, text='Ballgown', variable=v, value=11, command=sel).pack(anchor=W)
Radiobutton(root, text='turtleneck', variable=v, value=12, command=sel).pack(anchor=W) 
Radiobutton(root, text='skirts', variable=v, value=13, command=sel).pack(anchor=W)
Radiobutton(root, text='parka', variable=v, value=14, command=sel).pack(anchor=W) 
Radiobutton(root, text='sweatershirt', variable=v, value=15, command=sel).pack(anchor=W) 
Radiobutton(root, text='jeans', variable=v, value=16, command=sel).pack(anchor=W)
Radiobutton(root, text='romper', variable=v, value=17, command=sel).pack(anchor=W) 
Radiobutton(root, text='sweater', variable=v, value=18, command=sel).pack(anchor=W) 
Radiobutton(root, text='pullover', variable=v, value=19, command=sel).pack(anchor=W)
Radiobutton(root, text='jogger', variable=v, value=20, command=sel).pack(anchor=W) 

Radiobutton(root, text='Tee', variable=v, value=21, command=sel).pack(anchor=W)
Radiobutton(root, text='trench', variable=v, value=22, command=sel).pack(anchor=W) 
Radiobutton(root, text='trousers', variable=v, value=23, command=sel).pack(anchor=W)
Radiobutton(root, text='jacket', variable=v, value=24, command=sel).pack(anchor=W) 
Radiobutton(root, text='sweatshirt', variable=v, value=25, command=sel).pack(anchor=W) 
Radiobutton(root, text='kaftan', variable=v, value=26, command=sel).pack(anchor=W)
Radiobutton(root, text='suit', variable=v, value=27, command=sel).pack(anchor=W) 
Radiobutton(root, text='shift', variable=v, value=28, command=sel).pack(anchor=W) 
Radiobutton(root, text='mini', variable=v, value=29, command=sel).pack(anchor=W)
Radiobutton(root, text='coat', variable=v, value=30, command=sel).pack(anchor=W) 
Radiobutton(root, text='trouser', variable=v, value=31, command=sel).pack(anchor=W)
Radiobutton(root, text='cape', variable=v, value=32, command=sel).pack(anchor=W)
Radiobutton(root, text='top', variable=v, value=33, command=sel).pack(anchor=W)
mainloop()

import pandas as pd

def filter_needs(category, rented_for):
    # return a dataframe, each line <uid, iid, rating> (raw values: strings)
    rent_df = pd.DataFrame()
    for entry in rent_list:
        if entry['category'] == category and entry['rented for'] == rented_for:
            rent_df = rent_df.append(entry, ignore_index=True)
    return rent_df[['user_id', 'item_id', 'rating']]

category = sel()
#print(category)
my_df = filter_needs(category, rented_for = 'date')
# 'item_id': string 'user_id': string, 'rating': float (using 0 to represent null)
my_df
# = 'jacket'
# Out:
#    user_id  item_id  rating
# 0   822018  2046224     8.0
# 1   259082  2006660    10.0
# 2   997714  2758251    10.0
# 3    68298  2948324    10.0
# 4   587982  2427891     8.0
# 5    30583  2935830     6.0
# 6   371790  2044701    10.0
# 7   984625  2064239    10.0
# 8   781468  2738737     8.0
# 9   720098  2650470    10.0
# 10  326944  2356401     8.0
# 11  530978  2935830     6.0
# 12  454585  2369804    10.0
# 13  175829  2595491     8.0
# 14  758436  2758251     6.0
# 15  277673  2935830     6.0
# 16  164874  2319586    10.0
# 17  372201  2281848     8.0
# 18  687519  2158338     8.0
# 19  362951  2179097    10.0
# 20  126879  2511676    10.0
# 21   32023  2811715    10.0
# 22  950014  2055795    10.0
# 23  335469  2381464     8.0
# 24  214934  2925561    10.0
# 25   30568  2886958    10.0
# 26  729892  2758251    10.0
# 27  321684  2935830     8.0
# 28  919520  2417217    10.0
# 29  914196  2935830     8.0
# ..     ...      ...     ...
# 67  927346  2164018    10.0
# ...

# %%
# this part depends on my_df: filtered results
from surprise import Dataset
from surprise import Reader
from surprise.prediction_algorithms import KNNWithMeans
from surprise import accuracy
from surprise.model_selection import GridSearchCV

reader = Reader(rating_scale=(1, 10))
# The columns must correspond to user id, item id and ratings (in that order).
data = Dataset.load_from_df(my_df[['user_id', 'item_id', 'rating']], reader)

param_grid = {'k': [2, 3, 5, 7, 10, 12, 15, 17, 20], 
              'min_k': [1, 2, 3, 5, 7, 10],
              'sim_options': {'name': ['pearson'],
                              'min_support': [1, 2, 3, 5, 7, 10],
                              'user_based': [True]}}
# knnwithmeans decide the formula for prediction
# sim_options decide the formula for calculating similarities
# min_k: if there are not enough neighbors, prediction is the mean of all R_ui. 
# sim_options: min_support: min number of common items: if common items < min_support, sim(u, v)=0
knn_grid_search = GridSearchCV(KNNWithMeans, param_grid, measures=['rmse', 'mae'], cv=5)
# data is training + validation, GridSearchCV separates training and validation for me
# when fit, fit(trainval)
# test data is build_anti_testset: users and items are known, but ratings are unknown. 
knn_grid_search.fit(data)
print(knn_grid_search.best_score['rmse'])
print(knn_grid_search.best_params['rmse'])
algo = knn_grid_search.best_estimator['rmse']
trainvalset = data.build_full_trainset()
#algo.fit(trainvalset)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# ...

# %%
# predict: source: https://surprise.readthedocs.io/en/stable/FAQ.html
from collections import defaultdict

def get_top_n(predictions, n=10):
    '''Return the top-N recommendation for each user from a set of predictions.

    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    '''

    # First map the predictions to each user. A dictionary of lists. 
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# Then predict ratings for all pairs (u, i) that are NOT in the training set.
testset = trainvalset.build_anti_testset()
predictions = algo.test(testset)
top_n = get_top_n(predictions, n=10)
# print(top_n)
def recommend_for_user(uid):
    return top_n[uid]


# recommendation problems: some users may have tried some items and leave reviews in the dataset, 
# but they didn't rate. This system may recommend items that they have already tried before.
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-21-8d78803f1713> in <module>()
#      30 # Then predict ratings for all pairs (u, i) that are NOT in the training set.
#      31 testset = trainvalset.build_anti_testset()
# ---> 32 predictions = algo.test(testset)
#      33 top_n = get_top_n(predictions, n=10)
#      34 # print(top_n)
#
# C:\ProgramData\Anaconda\lib\site-packages\surprise\prediction_algorithms\algo_base.pyc in test(self, testset, verbose)
#     210                                     r_ui_trans - self.trainset.offset,
#     211                                     verbose=verbose)
# --> 212                        for (uid, iid, r_ui_trans) in testset]
#     213         return predictions
#     214
#
# AttributeError: 'KNNWithMeans' object has no attribute 'trainset'

# %%
# Get User ID GUI
import tkinter as tk

def get_userID():
    print(str(e1.get()))
                                       
master = tk.Tk()
tk.Label(master, text="User ID").grid(row=0)

e1 = tk.Entry(master)
e1.grid(row=0, column=1)
tk.Button(master, text='Quit', command=master.quit).grid(row=3, column=0, sticky=tk.W, pady=4)
tk.Button(master, text='Enter', command=get_userID).grid(row=3, column=1, sticky=tk.W, pady=4)

tk.mainloop()


ID = get_userID()
print(recommend_for_user(ID))
# Out:
# 4040
# TclErrorTraceback (most recent call last)
# <ipython-input-22-d8048b21e874> in <module>()
#      16
#      17
# ---> 18 ID = get_userID()
#      19 print(recommend_for_user(ID))
#
# <ipython-input-22-d8048b21e874> in get_userID()
#       3
#       4 def get_userID():
# ----> 5     print(str(e1.get()))
#       6
#       7 master = tk.Tk()
#
# C:\ProgramData\Anaconda\lib\lib-tk\Tkinter.pyc in get(self)
#    2516     def get(self):
#    2517         """Return the text."""
# -> 2518         return self.tk.call(self._w, 'get')
#    2519     def icursor(self, index):
#    2520         """Insert cursor at INDEX."""
#
# TclError: invalid command name ".435235976"

# %%
#import easygui
import tkinter as tk
from tkinter import ttk

def show():

    #tempList = [['Jim', '0.33'], ['Dave', '0.67'], ['James', '0.67'], ['Eden', '0.5']]
    #tempList.sort(key=lambda e: e[1], reverse=True)

    tempList = recommend_for_user('4040')
    
    for i, (item, rating) in enumerate(tempList, start=1):
        listBox.insert("", "end", values=(i, item, rating))

rating = tk.Tk() 
label = tk.Label(rating, text="Best Clothing for You", font=("Arial",30)).grid(row=0, columnspan=3)
# create Treeview with 3 columns
cols = ('Ranking', 'Item ID', 'Rating')

listBox = ttk.Treeview(rating, columns=cols, show='headings')
# set column headings
for col in cols:
    listBox.heading(col, text=col)    
listBox.grid(row=1, column=0, columnspan=2)

showScores = tk.Button(rating, text="Show scores", width=15, command=show).grid(row=4, column=0)
closeButton = tk.Button(rating, text="Close", width=15, command=exit).grid(row=4, column=1)

rating.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda\lib\lib-tk\Tkinter.py", line 1547, in __call__
#     return self.func(*args)
#   File "<ipython-input-15-ac51da8b3e72>", line 10, in show
#     tempList = recommend_for_user('4040')
# NameError: global name 'recommend_for_user' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda\lib\lib-tk\Tkinter.py", line 1547, in __call__
#     return self.func(*args)
#   File "<ipython-input-15-ac51da8b3e72>", line 10, in show
#     tempList = recommend_for_user('4040')
# NameError: global name 'recommend_for_user' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda\lib\lib-tk\Tkinter.py", line 1547, in __call__
#     return self.func(*args)
#   File "<ipython-input-15-ac51da8b3e72>", line 10, in show
#     tempList = recommend_for_user('4040')
# ...

# %%
import tkinter as tk
#from tkinter import ttk
"""
from tkinter import *
root = Tk() 
v = IntVar() 
Radiobutton(root, text='Legging', variable=v, value=1).pack(anchor=W) 
Radiobutton(root, text='Down', variable=v, value=2).pack(anchor=W) 
Radiobutton(root, text='Buttondown', variable=v, value=3).pack(anchor=W) 
"""

LARGE_FONT= ("Verdana", 12)


class SeaofBTCapp(tk.Tk):

    def __init__(self, *args, **kwargs):
        
        tk.Tk.__init__(self, *args, **kwargs)
        container = tk.Frame(self)

        container.pack(side="top", fill="both", expand = True)

        container.grid_rowconfigure(0, weight=1)
        container.grid_columnconfigure(0, weight=1)

        self.frames = {}

        for F in (StartPage, ResultPage):

            frame = F(container, self)

            self.frames[F] = frame

            frame.grid(row=0, column=0, sticky="nsew")

        self.show_frame(StartPage)

    def show_frame(self, cont):

        frame = self.frames[cont]
        frame.tkraise()

        
class StartPage(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self,parent)
        label = tk.Label(self, text="Welcome Page", font=LARGE_FONT)
        label.pack(pady=10,padx=10)
        
        tk.Label(self, text = "User ID").grid(row = 0) # this is placed in 0 0
        # 'Entry' is used to display the input-field
        tk.Entry(self).grid(row = 0, column = 1) # this is placed in 0 1
        
        
        # radio buttons
        v = tk.IntVar() 
        tk.Radiobutton(self, text='Legging', variable=v, value=1).pack()
        """
        
        tk.Radiobutton(self, text='Down', variable=v, value=2).pack(anchor=W)
        tk.Radiobutton(self, text='Buttondown', variable=v, value=3).pack(anchor=W)
        tk.Radiobutton(self, text='Crewneck', variable=v, value=4).pack(anchor=W)
        tk.Radiobutton(self, text='Gown', variable=v, value=5).pack(anchor=W)
        tk.Radiobutton(self, text='Hoodie', variable=v, value=6).pack(anchor=W)
        tk.Radiobutton(self, text='Caftan', variable=v, value=7).pack(anchor=W)
        tk.Radiobutton(self, text='Sheath', variable=v, value=8).pack(anchor=W)
        tk.Radiobutton(self, text='Leggings', variable=v, value=9).pack(anchor=W)
        tk.Radiobutton(self, text='Tank', variable=v, value=10).pack(anchor=W)
        tk.Radiobutton(self, text='Ballgown', variable=v, value=11).pack(anchor=W)
        tk.Radiobutton(self, text='Tunic', variable=v, value=12).pack(anchor=W)
        tk.Radiobutton(self, text='Turtleneck', variable=v, value=13).pack(anchor=W)
        tk.Radiobutton(self, text='Skirts', variable=v, value=14).pack(anchor=W)
        tk.Radiobutton(self, text='Parka', variable=v, value=15).pack(anchor=W)
        tk.Radiobutton(self, text='Sweatershirt', variable=v, value=16).pack(anchor=W)
        tk.Radiobutton(self, text='Jeans', variable=v, value=17).pack(anchor=W)
        tk.Radiobutton(self, text='Romper', variable=v, value=18).pack(anchor=W)
        tk.Radiobutton(self, text='Sweater', variable=v, value=19).pack(anchor=W)
        tk.Radiobutton(self, text='Pullover', variable=v, value=20).pack(anchor=W)
        #Radiobutton(root, text='Buttondown', variable=v, value=3).pack(anchor=W) 
        """
        button = tk.Button(self, text="Get Recommended Clothing",
                            command=lambda: controller.show_frame(ResultPage))
        
        button.pack()




class ResultPage(tk.Frame):

    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        label = tk.Label(self, text="Here are Recommended Clothing for You!!!", font=LARGE_FONT)
        label.pack(pady=10,padx=10)

        button1 = tk.Button(self, text="Back to Home",
                            command=lambda: controller.show_frame(StartPage))
        button1.pack()
        """
        button2 = tk.Button(self, text="Page Two",
                            command=lambda: controller.show_frame(PageTwo))
        button2.pack()
        """


app = SeaofBTCapp()
app.mainloop()
